# %% [markdown]
# # Medical insurance

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
# Load csv file 
df = pd.read_csv('../datasets/insurance.csv', index_col=False)

# %% [markdown]
# # Explanatory analysis
# ***
# ## Overview

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# ### Age

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

ax1.hist(df['age'], density=True, facecolor='g', alpha=0.75)
ax2.boxplot(df['age'])
ax3.scatter(df['age'],df['charges'],c=df['charges'], cmap = "RdBu_r", edgecolor = "Blue",marker='^',alpha=0.25)
plt.show()

# %%
df['age'].describe()
# Out:
# count    1338.000000
# mean       39.207025
# std        14.049960
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %% [markdown]
# ### Sex

# %%
df['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
df['sex'].describe()
# Out:
# count     1338
# unique       2
# top       male
# freq       676
# Name: sex, dtype: object

# %%
sns.countplot(x="sex", data=df)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
df['sex']= le.fit_transform(df['sex'])
df['sex'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1338 entries, 0 to 1337
# Series name: sex
# Non-Null Count  Dtype
# --------------  -----
# 1338 non-null   int64
# dtypes: int64(1)
# memory usage: 10.6 KB

# %% [markdown]
# ### BMI

# %%
df['bmi'].describe()
# Out:
# count    1338.000000
# mean       30.663397
# std         6.098187
# min        15.960000
# 25%        26.296250
# 50%        30.400000
# 75%        34.693750
# max        53.130000
# Name: bmi, dtype: float64

# %%
plt.boxplot(df['bmi'])
plt.show()

# %%
plt.scatter(df['bmi'],df['charges'],c=df['charges'], cmap = "RdBu_r", edgecolor = "Red",alpha=0.5)
plt.xlabel("BMI")
plt.ylabel("Insurance Cahrges")
plt.show()

# %% [markdown]
# ### Children

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

ax1.hist(df['children'], density=True, facecolor='g', alpha=0.75)
ax2.boxplot(df['children'])
ax3.scatter(df['children'],df['charges'], c=df['charges'] ,marker='o',alpha=0.25)
plt.show()

# %%
df['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
df['children'].describe()
# Out:
# count    1338.000000
# mean        1.094918
# std         1.205493
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         5.000000
# Name: children, dtype: float64

# %% [markdown]
# ### Smoker

# %%
df['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
df['smoker'].describe()
# Out:
# count     1338
# unique       2
# top         no
# freq      1064
# Name: smoker, dtype: object

# %%
sns.countplot(x="smoker", data=df)
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %%
df['smoker']= le.fit_transform(df['smoker'])
df['smoker'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1338 entries, 0 to 1337
# Series name: smoker
# Non-Null Count  Dtype
# --------------  -----
# 1338 non-null   int64
# dtypes: int64(1)
# memory usage: 10.6 KB

# %% [markdown]
# ### Regions

# %%
df['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
df['region'].describe()
# Out:
# count          1338
# unique            4
# top       southeast
# freq            364
# Name: region, dtype: object

# %%
sns.countplot(x="region", data=df)
# Out:
# <AxesSubplot:xlabel='region', ylabel='count'>

# %%
plt.scatter(df['region'],df['charges'], c=df['charges'] ,marker='o',alpha=0.5)

# %% [markdown]
# ## Relationships
